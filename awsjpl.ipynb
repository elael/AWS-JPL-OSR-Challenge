# %%
from elasticsearch import Elasticsearch 
es=Elasticsearch()
es.info(pretty=True)
# Out:
# {'name': '4dlV_zX',
#  'cluster_name': 'elasticsearch',
#  'cluster_uuid': 'lV2aOpYeSn-5Yg7XmO3h1Q',
#  'version': {'number': '6.8.6',
#   'build_flavor': 'default',
#   'build_type': 'deb',
#   'build_hash': '3d9f765',
#   'build_date': '2019-12-13T17:11:52.013738Z',
#   'build_snapshot': False,
#   'lucene_version': '7.7.2',
#   'minimum_wire_compatibility_version': '5.6.0',
#   'minimum_index_compatibility_version': '5.0.0'},
#  'tagline': 'You Know, for Search'}

# %%
import json
search_object = {'query': {'match': {'Episode_Reward': '0'}}}
res = es.search(index='logstash*', body=json.dumps(search_object))
res
# Out:
# {'took': 9,
#  'timed_out': False,
#  '_shards': {'total': 25, 'successful': 25, 'skipped': 0, 'failed': 0},
#  'hits': {'total': 13,
#   'max_score': 1.0,
#   'hits': [{'_index': 'logstash-2020.02.17',
#     '_type': 'doc',
#     '_id': 'QauzVHAB9-wkR_yOXgu4',
#     '_score': 1.0,
#     '_source': {'DistanceToCheckpoint': 44.2710929975093,
#      '@timestamp': '2020-02-17T19:50:06.152Z',
#      'logger_name': 'python-logstash-logger',
#      'Episode_Steps': 1,
#      'host': '345186c8def3',
#      'Episode_Reward': 0,
#      'message': 'episodic_rewards',
#      'stack_info': None,
#      'path': '/home/ubuntu/catkin_ws/src/simulation_ws/src/install/markov/lib/python3.6/site-packages/markov/environments/mars_env.py',
#      'tags': [],
#      'type': 'logstash',
#      'level': 'INFO',
#      '@version': '1'}},
#    {'_index': 'logstash-2020.02.18',
#     '_type': 'doc',
#     '_id': 'VjRLWnABrA5o8ynqaAb9',
#     '_score': 1.0,
#     '_source': {'tags': [],
#      'level': 'INFO',
# ...
